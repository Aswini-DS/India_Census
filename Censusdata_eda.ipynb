# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
censusdata = pd.read_excel("C:\\Users\\Lucky\\Downloads\\DataSets\\Dataset.xlsx")

# %%
censusdata.shape
# Out:
# (590, 82)

# %%
censusdata.head()
# Out:
#    X   State                                           District  Persons  \
# 0  1      AN  District Andamans (01), Andaman & Nicobar Isla...   314084
# 1  2      AN  District Nicobars (02), Andaman & Nicobar Isla...    42068
# 2  3  Andhra        District Adilabad (01), Andhra Pradesh (28)  2488003
# 3  4  Andhra       District Nizamabad (02), Andhra Pradesh (28)  2345685
# 4  5  Andhra      District Karimnagar (03), Andhra Pradesh (28)  3491822
#
#      Males  Females Growth..1991...2001.    Rural   Urban  \
# 0   170319   143765                30.14   197886  116198
# 1    22653    19415                 7.19    42068       -
# 2  1250958  1237045                19.06  1827986     NaN
# 3  1162905  1182780                14.98  1920947     NaN
# 4  1747968  1743854                14.47  2813010     NaN
#
#   Scheduled.Caste.population  ... Medical.facility  Primary.Health.Centre  \
# 0                          -  ...              102                     16
# ...

# %%
censusdata.describe(include='all')
# Out:
#                  X State        District       Persons         Males  \
# count   590.000000   590             590  5.900000e+02  5.900000e+02
# unique         NaN    35             589           NaN           NaN
# top            NaN    UP  District North           NaN           NaN
# freq           NaN    70               2           NaN           NaN
# mean    295.500000   NaN             NaN  1.732902e+06  8.966605e+05
# std     170.462606   NaN             NaN  1.329998e+06  6.934142e+05
# min       1.000000   NaN             NaN  3.139400e+04  1.589300e+04
# 25%     148.250000   NaN             NaN  8.127185e+05  4.207508e+05
# 50%     295.500000   NaN             NaN  1.487712e+06  7.706160e+05
# 75%     442.750000   NaN             NaN  2.395986e+06  1.248934e+06
# max     590.000000   NaN             NaN  9.610788e+06  4.916370e+06
#
#              Females Growth..1991...2001. Rural Urban  \
# count   5.900000e+02                  590   590    68
# ...

# %%
censusdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 82 columns):
# X                                         590 non-null int64
# State                                     590 non-null object
# District                                  590 non-null object
# Persons                                   590 non-null int64
# Males                                     590 non-null int64
# Females                                   590 non-null int64
# Growth..1991...2001.                      590 non-null object
# Rural                                     590 non-null object
# Urban                                     68 non-null object
# Scheduled.Caste.population                27 non-null object
# Percentage...SC.to.total                  28 non-null object
# Number.of.households                      587 non-null float64
# Household.size..per.household.            587 non-null float64
# ...

# %%
censusdata.replace('-','0',inplace=True)

# %%
censusdata.head()
# Out:
#    X   State                                           District  Persons  \
# 0  1      AN  District Andamans (01), Andaman & Nicobar Isla...   314084
# 1  2      AN  District Nicobars (02), Andaman & Nicobar Isla...    42068
# 2  3  Andhra        District Adilabad (01), Andhra Pradesh (28)  2488003
# 3  4  Andhra       District Nizamabad (02), Andhra Pradesh (28)  2345685
# 4  5  Andhra      District Karimnagar (03), Andhra Pradesh (28)  3491822
#
#      Males  Females Growth..1991...2001.    Rural   Urban  \
# 0   170319   143765                30.14   197886  116198
# 1    22653    19415                 7.19    42068       0
# 2  1250958  1237045                19.06  1827986     NaN
# 3  1162905  1182780                14.98  1920947     NaN
# 4  1747968  1743854                14.47  2813010     NaN
#
#   Scheduled.Caste.population  ... Medical.facility  Primary.Health.Centre  \
# 0                          0  ...              102                     16
# ...

# %%
censusdata.isna().sum()
# Out:
# X                        0
# State                    0
# District                 0
# Persons                  0
# Males                    0
#                         ..
# Paved.approach.road     12
# Mud.approach.road       12
# Permanent.House          0
# Semi.permanent.House     0
# Temporary.House          0
# Length: 82, dtype: int64

# %%
censusdata['Urban'] = censusdata['Urban'].fillna('0')
censusdata['Urban'] = censusdata['Urban'].astype(int)
censusdata['Rural'] = censusdata['Rural'].fillna('0')
censusdata['Rural'] = censusdata['Rural'].astype(int)

# %%
#As Total Population is divided into Urban and Rural, Filling Urban NaN values into Population-Rural and vise-versa for Urban

censusdata['Urban'].replace(0,censusdata.Persons - censusdata.Rural,inplace=True)

# %%
censusdata['Rural'].replace(0,censusdata.Persons - censusdata.Urban,inplace=True)

# %%
censusdata.head()
# Out:
#    X   State                                           District  Persons  \
# 0  1      AN  District Andamans (01), Andaman & Nicobar Isla...   314084
# 1  2      AN  District Nicobars (02), Andaman & Nicobar Isla...    42068
# 2  3  Andhra        District Adilabad (01), Andhra Pradesh (28)  2488003
# 3  4  Andhra       District Nizamabad (02), Andhra Pradesh (28)  2345685
# 4  5  Andhra      District Karimnagar (03), Andhra Pradesh (28)  3491822
#
#      Males  Females Growth..1991...2001.    Rural   Urban  \
# 0   170319   143765                30.14   197886  116198
# 1    22653    19415                 7.19    42068       0
# 2  1250958  1237045                19.06  1827986  660017
# 3  1162905  1182780                14.98  1920947  424738
# 4  1747968  1743854                14.47  2813010  678812
#
#   Scheduled.Caste.population  ... Medical.facility  Primary.Health.Centre  \
# 0                          0  ...              102                     16
# ...

# %%
censusdata['State'].value_counts()
# Out:
# UP                  70
# MP                  45
# Bihar               37
# Maharashtra         35
# Rajasthan           32
# TN                  30
# Orrisa              29
# Karnataka           27
# Gujarat             25
# Assam               23
# Andhra              22
# Haryana             19
# Jharkhand           18
# WB                  18
# Punjab              17
# CG                  16
# JK                  14
# Kerala              14
# ArunachalPradesh    13
# Uttranchal          13
# HP                  12
# Delhi                9
# Manipur              8
# Mizoram              8
# Nagaland             8
# Meghalya             7
# Tripura              4
# Pondicherry          4
# Sikkim               4
# AN                   2
# D_D                  2
# Goa                  2
# Lakshdweep           1
# D_N_H                1
# Chandigarh           1
# Name: State, dtype: int64

# %% [markdown]
# ### States with Highest Population

# %%
censusdata.groupby('State').sum().sort_values(['Persons'],ascending=False)
# Out:
#                       X    Persons     Males   Females      Rural     Urban  \
# State
# UP                36715  166197921  87565369  78632552  131658339  34539582
# Maharashtra        9660   96878627  50400596  46478031   55777647  41100980
# Bihar              2923   82998509  43243795  39754714   74316709   8681800
# WB                10467   80176197  41465985  38710212   57748946  22427251
# Andhra              297   71308587  36067773  35240814   51651532  19657055
# TN                14115   62405679  31400909  31004770   34921681  27483998
# MP                15255   60348023  31443652  28904371   44380878  15967145
# Rajasthan         13936   56507188  29420011  27087177   43292813  13214375
# Karnataka          6210   52850562  26898918  25951644   34889033  17961529
# Gujarat            3525   50671017  26385577  24285440   31740767  18930250
# Orrisa            11136   35664657  18073336  17591321   30305835   5358822
# ...

# %%
censusdata.groupby('State')[["Persons"]].sum().sort_values(['Persons'],ascending=False).plot(kind='bar')

# %%
count =censusdata['State'].value_counts()
count.plot("bar")
plt.xlabel("State name",size=20,color='g')
plt.ylabel("No. of cities", size=20,color='orange')
plt.title("Cities per state", size= 20)
# Out:
# C:\Users\Lucky\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# Text(0.5, 1.0, 'Cities per state')

# %%
sizes = [sum(censusdata['Males']),sum(censusdata['Females'])]
labels =  'Males','Females'
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1da1203edd8>,
# ...
#  [Text(-0.06021314585846363, 1.0983507532049257, 'Males'),
#   Text(0.060213043023444386, -1.0983507588424826, 'Females')],
#  [Text(-0.03284353410461652, 0.5991004108390503, '51.7%'),
#   Text(0.03284347801278784, -0.5991004139140813, '48.3%')])

# %%
Population = [sum(censusdata['Urban']),sum(censusdata['Rural'])]
labels =  'Urban','Rural'
plt.pie(Population,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1da12087898>,
# ...
#  [Text(0.7049774895325558, 0.8443972638825729, 'Urban'),
#   Text(-0.7049775685907305, -0.8443971978778128, 'Rural')],
#  [Text(0.3845331761086667, 0.4605803257541306, '27.9%'),
#   Text(-0.38453321923130745, -0.4605802897515342, '72.1%')])

# %% [markdown]
# #### Population is more in Rural Area's then Urban Area's

# %%
censusdata.groupby('State')[["Males","Females"]].sum().sort_values(["Males","Females"],ascending=False).plot(kind='bar',figsize=(15,10))

# %%
censusdata['Growth..1991...2001.'] = censusdata['Growth..1991...2001.'].str.strip('()').astype(float)

# %%
censusdata.groupby('State')[["Growth..1991...2001."]].sum().sort_values(['Growth..1991...2001.'],ascending=False).plot(kind='bar',figsize=(15,10))

# %% [markdown]
# #### Above graph's shows UP is having high Population and More Growth rate

# %% [markdown]
# ## __Education Level in India__

# %%
censusdata['Graduate.and.Above'].fillna(0,inplace=True)
censusdata['Below.Primary'].fillna(0,inplace=True)
censusdata['Primary'].fillna(0,inplace=True)
censusdata['Middle'].fillna(0,inplace=True)
censusdata['Matric.Higher.Secondary.Diploma'].fillna(0,inplace=True)

# %%
labels = 'Graduate.and.Above','Below.Primary', 'Primary', 'Middle','Matric.Higher.Secondary.Diploma'
explode = (0.1, 0, 0, 0,0)
education = [sum(censusdata['Graduate.and.Above']),sum(censusdata['Below.Primary']),sum(censusdata['Primary']),sum(censusdata['Middle']),sum(censusdata['Matric.Higher.Secondary.Diploma'])]
plt.pie(education,explode=explode, labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1da1230e8d0>,
# ...
#  [Text(1.1711967460898656, 0.26133920859394816, 'Graduate.and.Above'),
#   Text(0.3151169698985784, 1.0538981427452743, 'Below.Primary'),
#   Text(-1.0841780336508837, 0.18589779812817367, 'Primary'),
#   Text(-0.3918907657576022, -1.027823733776332, 'Middle'),
#   Text(0.8381031991452966, -0.7124486139943143, 'Matric.Higher.Secondary.Diploma')],
#  [Text(0.6831981018857548, 0.15244787167980306, '7.0%'),
#   Text(0.17188198358104273, 0.5748535324065132, '26.8%'),
#   Text(-0.5913698365368456, 0.10139879897900382, '27.1%'),
#   Text(-0.2137585995041466, -0.560631127514363, '16.7%'),
#   Text(0.4571471995337981, -0.38860833490598956, '22.4%')])

# %%
censusdata.groupby('State')[["Graduate.and.Above","Below.Primary","Primary","Middle","Matric.Higher.Secondary.Diploma"]].sum().plot(kind='bar',stacked=True,figsize=(15,10))

# %% [markdown]
# #### As per above plot Daman and Diu , Dadra and Nagar Haveli and Lakshdweep are having very low education facilities

# %%
literate = [sum(censusdata['Males..Literate']),sum(censusdata['Females..Literate'])]
labels =  'Male Literate','Female Literate'
plt.pie(literate,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1da128761d0>,
# ...
#  [Text(-0.3416643326861965, 1.0455933644443696, 'Male Literate'),
#   Text(0.3416643326861959, -1.0455933644443698, 'Female Literate')],
#  [Text(-0.18636236328337988, 0.5703236533332924, '60.1%'),
#   Text(0.18636236328337955, -0.5703236533332925, '39.9%')])

# %%
censusdata.groupby('State').apply(lambda x: x['Persons..literacy.rate'].sum() / x['Persons'].sum()).plot(kind='bar',figsize=(10,10))

# %% [markdown]
# #### As per above plots literacy rate per person is very low in West Bangal , Bihar and Andhra

# %%
censusdata.groupby('State').apply(lambda x: x['Drinking.water.facilities'].sum() / x['Persons'].sum()).plot(kind='bar',figsize=(10,10))

# %% [markdown]
# #### As per above plots Delhi and Chandigarh are having low Driniking water facilities

# %%
censusdata.groupby('State')[["Permanent.House","Semi.permanent.House","Temporary.House"]].sum().plot(kind='bar',stacked=True,figsize=(15,10))

# %%
censusdata.groupby('State').apply(lambda x: x['Post..telegraph.and.telephone.facility'].sum() / x['Persons'].sum()).plot(kind='bar',figsize=(10,10))

# %% [markdown]
# #### As per above plots HP is having better communication facilities

# %%
censusdata.groupby('State')[["Sex.ratio..females.per.1000.males."]].sum().plot(kind='bar',figsize=(10,10))

# %% [markdown]
# #### Chandigarh is having low female to male ratio

# %%
censusdata.groupby('State')[["X0...4.years","X5...14.years","X15...59.years","X60.years.and.above..Incl..A.N.S.."]].sum().plot(kind='bar',stacked=True,figsize=(15,10))

# %% [markdown]
# #### More polulation in all states is at the age of 15-59 years

# %%
basicfacilities = censusdata[['State','Persons','Safe.Drinking.water','Electricity..Power.Supply.','Primary.school','Middle.schools','Secondary.Sr.Secondary.schools','College','Medical.facility','Post..telegraph.and.telephone.facility','Bus.services','Paved.approach.road','Permanent.House']].groupby('State').sum().reset_index()
basicfacilities.head()
# Out:
#               State   Persons  Safe.Drinking.water  \
# 0                AN    356152                456.0
# 1            Andhra  71308587              23794.0
# 2  ArunachalPradesh   1097968               3185.0
# 3             Assam  26655528              24067.0
# 4             Bihar  82998509              38935.0
#
#    Electricity..Power.Supply.  Primary.school  \
# 0                       329.0           238.0
# 1                     25275.0         23702.0
# 2                      1652.0          1575.0
# 3                     17037.0         21283.0
# 4                     14135.0         28330.0
#
#    Post..telegraph.and.telephone.facility  Permanent.House
# 0                                   197.0             56.7
# 1                                 16383.0           1189.5
# 2                                   328.0            269.6
# 3                                  5818.0            420.4
# 4                                 10157.0           1468.1

# %%
for i in range(2,len(basicfacilities.columns)):
    basicfacilities.iloc[:,i]=basicfacilities.iloc[:,i]/basicfacilities['Persons']

# %%
basicfacilities.head()
# Out:
#               State   Persons  Safe.Drinking.water  \
# 0                AN    356152             0.001280
# 1            Andhra  71308587             0.000334
# 2  ArunachalPradesh   1097968             0.002901
# 3             Assam  26655528             0.000903
# 4             Bihar  82998509             0.000469
#
#    Electricity..Power.Supply.  Primary.school  \
# 0                    0.000924        0.000668
# 1                    0.000354        0.000332
# 2                    0.001505        0.001434
# 3                    0.000639        0.000798
# 4                    0.000170        0.000341
#
#    Post..telegraph.and.telephone.facility  Permanent.House
# 0                                0.000553         0.000159
# 1                                0.000230         0.000017
# 2                                0.000299         0.000246
# 3                                0.000218         0.000016
# 4                                0.000122         0.000018

# %%
basicfacilities.drop(['Persons'],inplace=True,axis=1)

# %%
basicfacilities.plot(x='State',kind='bar',width=1,figsize=(30,10))

# %% [markdown]
# ##### HP is providing better facilities for living
